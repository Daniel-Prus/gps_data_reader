# %%
import numpy as np
import pandas as pd
from gps_data_reader.db_manager import DBManager

# %%
help(DBManager)
# Out:
# Help on class DBManager in module gps_data_reader.db_manager:
#
# class DBManager(builtins.object)
#  |  DBManager(database)
#  |
#  |  Class creates and allows to manage SQLite databases for gps signal data.
#  |
#  |  'Attributes'
#  |      ------------
#  |          database (str): name/path of database. If not exists creates new database.
#  |
#  |  Methods defined here:
#  |
#  |  __del__(self)
#  |
#  |  __init__(self, database)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  begin_transaction(self)
#  |
#  |  close(self)
#  |
#  |  commit(self)
#  |
#  |  create_table(self, table: str)
#  |      Creates empty gps table with columns:
#  |      "id", "dt", "vehicle", "driver", "position", "country",
#  |      "speed", "mileage", "ignition_status", "engine_status",
#  |      "longitude", "latitude".
#  |
#  |      Parameters
#  |      ----------
#  |          table (str): table name.
#  |
#  |  drop_duplicates(self, table)
#  |
#  |  drop_table(self, table)
#  |
#  |  find_duplicates(self, table)
#  |
#  |  get_column_names(self, table)
#  |
#  |  info(self)
#  |      Get specifications of database tables.
#  |
#  |  insert_dataframe(self, table, df, if_exists='append')
#  |      Insert values as pandas dataframe.
#  |
#  |  insert_values(self, table, values: list)
#  |
#  |  rollback(self)
#  |
#  |  search_values(self, table, vehicle='', driver='', between=None)
#  |      Search values by filter arguments.
#  |
#  |      'Parameters'
#  |      ------------
#  |          table (str): table name - 'gps'.
#  |          vehicle (str, optional): registration number of the vehicle.
#  |          driver (str, optional): driver name/surname.
#  |          date_range(list of str, optional): start/end date of route. Format - ["yyyy-mm-dd", "yyyy-mm-dd"].
#  |                                              Default - None.
#  |
#  |      'Yields'
#  |      ----------
#  |          generator object
#  |
#  |  table_length(self, table)
#  |
#  |  total_changes(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  delete_database(database)
#  |
#  |  generator_converter(generator)
#  |      Convert generator to numpy array.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
gps = pd.read_pickle('gps_data.pickle')
gps
# Out:
#                       dt  vehicle      driver  \
# 0    2019-06-25 01:43:00  PL12345  Nowak, Jan
# 1    2019-06-25 02:03:00  PL12345  Nowak, Jan
# 2    2019-06-25 02:13:00  PL12345  Nowak, Jan
# 3    2019-06-25 02:23:00  PL12345  Nowak, Jan
# 4    2019-06-25 11:02:00  PL12345  Nowak, Jan
# ...                  ...      ...         ...
# 1179 2019-07-24 20:29:00  PL12345  Nowak, Jan
# 1180 2019-07-24 20:39:00  PL12345  Nowak, Jan
# 1181 2019-07-24 20:49:00  PL12345  Nowak, Jan
# 1182 2019-07-24 20:59:00  PL12345  Nowak, Jan
# 1183 2019-07-24 20:59:00  PL12345  Nowak, Jan
#
#                                      position country  speed  mileage  \
# 0      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# 1      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# 2      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# 3      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# 4      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# ...                                       ...     ...    ...      ...
# 1179                 A30, 49492 Westerkappeln     DEU   84.0  39797.8
# 1180                    A30, 49479 Ibbenbüren     DEU   84.0  39812.0
# 1181                        A30, 48432 Rheine     DEU   70.0  39826.2
# 1182           Bonifatiusstraße, 48432 Rheine     DEU   15.0  39831.1
# 1183           Bonifatiusstraße, 48432 Rheine     DEU    NaN      NaN
#
#       ignition_status  engine_status  longitude   latitude
# 0                True          False  11.490252  52.179932
# 1                True          False  11.490252  52.179928
# 2                True          False  11.490252  52.179928
# 3                True          False  11.490252  52.179932
# 4                True           True  11.490245  52.179932
# ...               ...            ...        ...        ...
# 1179             True           True   7.879366  52.263775
# 1180             True           True   7.680992  52.264351
# 1181             True           True   7.491128  52.303776
# 1182             True           True   7.450903  52.306171
# 1183            False          False   7.450903  52.306171
#
# [1184 rows x 11 columns]

# %% [markdown]
# #### 1. Test database.

# %%
db_test = DBManager("test_db")
db_test
# Out:
# Database (test_db)

# %%
db_test.info()
# Out:
# Database - test_db is empty.

# %%
db_test.delete_database("test_db")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5460/1118376965.py in <module>
# ----> 1 db_test.delete_database("test_db")
#
# C:\PythonScripts\gps_data_reader\gps_data_reader\gps_data_reader\db_manager.py in delete_database(database)
#     189     @staticmethod
#     190     def delete_database(database):
# --> 191         os.remove(database)
#     192         print(f'{str(database)} deleted succesfully.')
#     193
#
# PermissionError: [WinError 32] Proces nie może uzyskać dostępu do pliku, ponieważ jest on używany przez inny proces: 'test_db'

# %%
db_test.close()
db_test.delete_database("test_db")
# Out:
# test_db deleted succesfully.

# %% [markdown]
# #### 2. Create database for default transport company.

# %%
db = DBManager("company_xyz.db")

# %%
db.database
# Out:
# 'company_db'

# %%
db.info()
# Out:
# 	========================
#  	  Database: company_db
#  	========================
#
# tables:
#    gps
# ========================
#
# gps table (1188 rows):
#
#                  cid       type  notnull dflt_value  pk
# name
# id                 0    INTEGER        1       None   1
# dt                 1  TIMESTAMP        1       None   0
# vehicle            2       TEXT        0       None   0
# driver             3       TEXT        0       None   0
# position           4       TEXT        0       None   0
# country            5       TEXT        0       None   0
# speed              6    INTEGER        0       None   0
# mileage            7       REAL        0       None   0
# ignition_status    8    INTEGER        0       None   0
# engine_status      9    INTEGER        0       None   0
# longitude         10       REAL        0       None   0
# latitude          11       REAL        0       None   0
# ==================================================

# %%
db.create_table("gps")

# %%
db.info()
# Out:
# 	========================
#  	  Database: company_db
#  	========================
#
# tables:
#    gps
# ========================
#
# gps table (1188 rows):
#
#                  cid       type  notnull dflt_value  pk
# name
# id                 0    INTEGER        1       None   1
# dt                 1  TIMESTAMP        1       None   0
# vehicle            2       TEXT        0       None   0
# driver             3       TEXT        0       None   0
# position           4       TEXT        0       None   0
# country            5       TEXT        0       None   0
# speed              6    INTEGER        0       None   0
# mileage            7       REAL        0       None   0
# ignition_status    8    INTEGER        0       None   0
# engine_status      9    INTEGER        0       None   0
# longitude         10       REAL        0       None   0
# latitude          11       REAL        0       None   0
# ==================================================

# %% [markdown]
# #### 3. Insert data as dataframe.

# %%
db.insert_dataframe("gps", gps)

# %%
db.info()
# Out:
# 	========================
#  	  Database: company_db
#  	========================
#
# tables:
#    gps
# ========================
#
# gps table (2372 rows):
#
#                  cid       type  notnull dflt_value  pk
# name
# id                 0    INTEGER        1       None   1
# dt                 1  TIMESTAMP        1       None   0
# vehicle            2       TEXT        0       None   0
# driver             3       TEXT        0       None   0
# position           4       TEXT        0       None   0
# country            5       TEXT        0       None   0
# speed              6    INTEGER        0       None   0
# mileage            7       REAL        0       None   0
# ignition_status    8    INTEGER        0       None   0
# engine_status      9    INTEGER        0       None   0
# longitude         10       REAL        0       None   0
# latitude          11       REAL        0       None   0
# ==================================================

# %% [markdown]
# #### 4. Search for duplicates.

# %%
db.find_duplicates("gps")
# Out:
#         id                   dt  vehicle      driver  \
# 0        1  2019-06-25 01:43:00  PL12345  Nowak, Jan
# 795    796  2019-07-15 19:17:00  PL12345  Nowak, Jan
# 793    794  2019-07-15 18:57:00  PL12345  Nowak, Jan
# 792    793  2019-07-15 18:47:00  PL12345  Nowak, Jan
# 791    792  2019-07-15 18:23:00  PL12345  Nowak, Jan
# ...    ...                  ...      ...         ...
# 394    395  2019-07-04 14:55:00  PL12345  Nowak, Jan
# 393    394  2019-07-04 14:45:00  PL12345  Nowak, Jan
# 392    393  2019-07-04 14:35:00  PL12345  Nowak, Jan
# 391    392  2019-07-04 14:25:00  PL12345  Nowak, Jan
# 1183  1183  2019-07-24 20:59:00  PL12345  Nowak, Jan
#
#                                      position country  speed  mileage  \
# 0      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# 795                        A2, 39343 Erxleben     DEU   85.0  35827.6
# 793                       A2, 38350 Helmstedt     DEU   85.0  35799.3
# 792                   A2, 38154 Königslutter      DEU   83.0  35785.1
# 791                    A2, 38110 Braunschweig     DEU   84.0  35766.9
# ...                                       ...     ...    ...      ...
# 394                          A44, 59494 Soest     DEU   83.0  31610.4
# 393                           A44, 59427 Unna     DEU   83.0  31596.6
# 392                     A1, 59439 Holzwickede     DEU   84.0  31583.4
# 391                        A1, 58239 Schwerte     DEU   46.0  31574.9
# 1183           Bonifatiusstraße, 48432 Rheine     DEU   15.0  39831.1
#
#       ignition_status  engine_status  longitude   latitude  COUNT(*)
# 0                   1              0  11.490252  52.179932         2
# 795                 1              1  11.306891  52.191170         2
# 793                 1              1  10.940000  52.276199         2
# 792                 1              1  10.749052  52.310631         2
# 791                 1              1  10.516127  52.314659         2
# ...               ...            ...        ...        ...       ...
# 394                 1              1   8.008015  51.539074         2
# 393                 1              1   7.814453  51.530163         2
# 392                 1              1   7.649241  51.505131         2
# 391                 1              1   7.558947  51.456459         2
# 1183                1              1   7.450903  52.306171         2
#
# [1184 rows x 13 columns]

# %%
db.insert_dataframe("gps", gps)

# %%
db.find_duplicates("gps")
# Out:
#         id                   dt  vehicle      driver  \
# 0        1  2019-06-25 01:43:00  PL12345  Nowak, Jan
# 795    796  2019-07-15 19:17:00  PL12345  Nowak, Jan
# 793    794  2019-07-15 18:57:00  PL12345  Nowak, Jan
# 792    793  2019-07-15 18:47:00  PL12345  Nowak, Jan
# 791    792  2019-07-15 18:23:00  PL12345  Nowak, Jan
# ...    ...                  ...      ...         ...
# 394    395  2019-07-04 14:55:00  PL12345  Nowak, Jan
# 393    394  2019-07-04 14:45:00  PL12345  Nowak, Jan
# 392    393  2019-07-04 14:35:00  PL12345  Nowak, Jan
# 391    392  2019-07-04 14:25:00  PL12345  Nowak, Jan
# 1183  1183  2019-07-24 20:59:00  PL12345  Nowak, Jan
#
#                                      position country  speed  mileage  \
# 0      Wolmirstedter Straße, 39326 Hohe Börde     DEU    NaN  27533.0
# 795                        A2, 39343 Erxleben     DEU   85.0  35827.6
# 793                       A2, 38350 Helmstedt     DEU   85.0  35799.3
# 792                   A2, 38154 Königslutter      DEU   83.0  35785.1
# 791                    A2, 38110 Braunschweig     DEU   84.0  35766.9
# ...                                       ...     ...    ...      ...
# 394                          A44, 59494 Soest     DEU   83.0  31610.4
# 393                           A44, 59427 Unna     DEU   83.0  31596.6
# 392                     A1, 59439 Holzwickede     DEU   84.0  31583.4
# 391                        A1, 58239 Schwerte     DEU   46.0  31574.9
# 1183           Bonifatiusstraße, 48432 Rheine     DEU   15.0  39831.1
#
#       ignition_status  engine_status  longitude   latitude  COUNT(*)
# 0                   1              0  11.490252  52.179932         3
# 795                 1              1  11.306891  52.191170         3
# 793                 1              1  10.940000  52.276199         3
# 792                 1              1  10.749052  52.310631         3
# 791                 1              1  10.516127  52.314659         3
# ...               ...            ...        ...        ...       ...
# 394                 1              1   8.008015  51.539074         3
# 393                 1              1   7.814453  51.530163         3
# 392                 1              1   7.649241  51.505131         3
# 391                 1              1   7.558947  51.456459         3
# 1183                1              1   7.450903  52.306171         3
#
# [1184 rows x 13 columns]

# %%
db.drop_duplicates("gps")
# Out:
# Duplicates dropped - 2368 rows.

# %% [markdown]
# #### 4. Insert rows, search, drop.

# %%
test_values =[('2021-11-11 01:43:00','PL55555', 'John Smith', 'Chernobyl 1234', 'UKR', 88.1212, 500533.0, 1, 0, 11.490252, 52.179932),
              ('2021-11-11 05:50:00','PL55555', 'John Smith', 'Chernobyl 1234', 'UKR',  20, 500533.0, 0, 0, 11.490252, 52.179932),
              ('2021-08-05 12:50:00','GB06666', 'Jan Kowalski', 'Warszawa, Mokotów 1234', 'PL', 50,  121121.0, 1, 1, 5.881000, 12.124566),
              ('2021-08-05 12:50:00','GB06666', 'Jan Kowalski', 'Warszawa, Mokotów 1234', 'PL', 50, 121121.0, 1, 1, 5.881000, 12.124566),
              ('2020-09-05 19:23:00','BI122', 'Elon Musk', 'Gdańsk 8', 'PL', 0,  521121.0, 1, 1, 7.450903, 52.306171)]

# %%
db.insert_values("gps", values=test_values)
# Out:
# 5 rows added.

# %%
gen = db.search_values("gps", vehicle="PL55555")

# %%
db.generator_converter(gen)
# Out:
# array([['1185', '2021-11-11 01:43:00', 'PL55555', 'John Smith', 'Chernobyl 1234', 'UKR', '88.1212', '500533.0', '1', '0', '11.490252', '52.179932'],
#        ['1186', '2021-11-11 05:50:00', 'PL55555', 'John Smith', 'Chernobyl 1234', 'UKR', '20', '500533.0', '0', '0', '11.490252', '52.179932'],
#        ['1190', '2021-11-11 01:43:00', 'PL55555', 'John Smith', 'Chernobyl 1234', 'UKR', '88.1212', '500533.0', '1', '0', '11.490252', '52.179932'],
#        ['1191', '2021-11-11 05:50:00', 'PL55555', 'John Smith', 'Chernobyl 1234', 'UKR', '20', '500533.0', '0', '0', '11.490252', '52.179932']], dtype='<U32')

# %%
db.find_duplicates("gps")
# Out:
#         id                   dt  vehicle        driver  \
# 1185  1187  2021-08-05 12:50:00  GB06666  Jan Kowalski
# 1184  1189  2020-09-05 19:23:00    BI122     Elon Musk
# 1186  1185  2021-11-11 01:43:00  PL55555    John Smith
# 1187  1186  2021-11-11 05:50:00  PL55555    John Smith
#
#                     position country    speed   mileage  ignition_status  \
# 1185  Warszawa, Mokotów 1234      PL  50.0000  121121.0                1
# 1184                Gdańsk 8      PL   0.0000  521121.0                1
# 1186          Chernobyl 1234     UKR  88.1212  500533.0                1
# 1187          Chernobyl 1234     UKR  20.0000  500533.0                0
#
#       engine_status  longitude   latitude  COUNT(*)
# 1185              1   5.881000  12.124566         3
# 1184              1   7.450903  52.306171         2
# 1186              0  11.490252  52.179932         2
# 1187              0  11.490252  52.179932         2

# %%
db.drop_duplicates("gps")
# Out:
# Duplicates dropped - 5 rows.

# %%
db.table_length("gps")
# Out:
# 1188

# %%
db.total_changes()
# Out:
# 4746

# %%
db.info()
# Out:
# 	========================
#  	  Database: company_db
#  	========================
#
# tables:
#    gps
# ========================
#
# gps table (1188 rows):
#
#                  cid       type  notnull dflt_value  pk
# name
# id                 0    INTEGER        1       None   1
# dt                 1  TIMESTAMP        1       None   0
# vehicle            2       TEXT        0       None   0
# driver             3       TEXT        0       None   0
# position           4       TEXT        0       None   0
# country            5       TEXT        0       None   0
# speed              6    INTEGER        0       None   0
# mileage            7       REAL        0       None   0
# ignition_status    8    INTEGER        0       None   0
# engine_status      9    INTEGER        0       None   0
# longitude         10       REAL        0       None   0
# latitude          11       REAL        0       None   0
# ==================================================

# %%
# close connection
db.close()
